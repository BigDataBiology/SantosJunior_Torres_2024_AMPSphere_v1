# %%
def get_assembly_summary(id):
    """Get esummary for an entrez id"""
    from Bio import Entrez
    esummary_handle = Entrez.esummary(db="assembly", id=id, report="full")
    esummary_record = Entrez.read(esummary_handle)
    return esummary_record

# %%
def get_assemblies(term, download=True, path='assemblies'):
    """Download genbank assemblies for a given search term.
    Args:
        term: search term, usually organism name
        download: whether to download the results
        path: folder to save to
    """
    import os, urllib
    from Bio import Entrez
    #provide your own mail here
    Entrez.email = "A.N.Other@example.com"
    handle = Entrez.esearch(db="assembly", term=term, retmax='200')
    record = Entrez.read(handle)
    ids = record['IdList']
    print (f'found {len(ids)} ids')
    links = []
    for id in ids:
        #get summary
        summary = get_assembly_summary(id)
        #get ftp link
        url = summary['DocumentSummarySet']['DocumentSummary'][0]['FtpPath_RefSeq']
        if url == '':
            continue
        label = os.path.basename(url)
        #get the fasta link - change this to get other formats
        link = os.path.join(url,label+'_genomic.fna.gz')
        print (link)
        links.append(link)
        if download == True:
            #download link
            urllib.request.urlretrieve(link, f'{label}.fna.gz')
    return links

# %%
# get samples
import pandas as pd
samples = pd.read_table('progenomes_cluster1969.tsv', sep='\t', header='infer')
samples
# Out:
#                           species        sample rep               cluster  \
# 0           Mycoplasma pneumoniae  SAMN03142252  No  specI_v3_Cluster1969
# 1           Mycoplasma pneumoniae  SAMN03142253  No  specI_v3_Cluster1969
# 2           Mycoplasma pneumoniae  SAMN03142254  No  specI_v3_Cluster1969
# 3           Mycoplasma pneumoniae  SAMN03142256  No  specI_v3_Cluster1969
# 4           Mycoplasma pneumoniae  SAMN03142257  No  specI_v3_Cluster1969
# ..                            ...           ...  ..                   ...
# 71    Mycoplasma pneumoniae M2592  SAMN03284393  No  specI_v3_Cluster1969
# 72      Mycoplasma pneumoniae M29  SAMN02582400  No  specI_v3_Cluster1969
# 73      Mycoplasma pneumoniae MAC  SAMN03284394  No  specI_v3_Cluster1969
# 74  Mycoplasma pneumoniae PI 1428  SAMN02471520  No  specI_v3_Cluster1969
# 75      Mycoplasma pneumoniae PO1  SAMN02471519  No  specI_v3_Cluster1969
#
#     genes  contigs
# 0    1340       29
# 1    1401       20
# 2    1364       44
# 3    1391       16
# 4    1397       18
# ..    ...      ...
# 71    743        1
# 72   1503        1
# 73    742        1
# 74    746        1
# 75    744        1
#
# [76 rows x 6 columns]

# %%
for x in samples['sample']:
    print(x)
    links = get_assemblies(x,
                           download=True)
# Out:
# SAMN03142252
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/455/635/GCF_001455635.1_ASM145563v1/GCF_001455635.1_ASM145563v1_genomic.fna.gz
# SAMN03142253
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/455/795/GCF_001455795.1_ASM145579v1/GCF_001455795.1_ASM145579v1_genomic.fna.gz
# SAMN03142254
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/455/625/GCF_001455625.1_ASM145562v1/GCF_001455625.1_ASM145562v1_genomic.fna.gz
# SAMN03142256
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/455/675/GCF_001455675.1_ASM145567v1/GCF_001455675.1_ASM145567v1_genomic.fna.gz
# SAMN03142257
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/296/805/GCF_001296805.1_ASM129680v1/GCF_001296805.1_ASM129680v1_genomic.fna.gz
# SAMN04370656
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/509/195/GCF_001509195.1_ASM150919v1/GCF_001509195.1_ASM150919v1_genomic.fna.gz
# SAMN04451628
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/558/175/GCF_001558175.1_ASM155817v1/GCF_001558175.1_ASM155817v1_genomic.fna.gz
# SAMN05391692
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/901/705/GCF_001901705.1_ASM190170v1/GCF_001901705.1_ASM190170v1_genomic.fna.gz
# SAMN05391693
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/127/985/GCF_002127985.1_ASM212798v1/GCF_002127985.1_ASM212798v1_genomic.fna.gz
# SAMN05391695
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/005/GCF_002128005.1_ASM212800v1/GCF_002128005.1_ASM212800v1_genomic.fna.gz
# SAMN05391698
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/025/GCF_002128025.1_ASM212802v1/GCF_002128025.1_ASM212802v1_genomic.fna.gz
# SAMN05391700
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/045/GCF_002128045.1_ASM212804v1/GCF_002128045.1_ASM212804v1_genomic.fna.gz
# SAMN05391704
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/065/GCF_002128065.1_ASM212806v1/GCF_002128065.1_ASM212806v1_genomic.fna.gz
# SAMN05391706
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/145/GCF_002128145.1_ASM212814v1/GCF_002128145.1_ASM212814v1_genomic.fna.gz
# SAMN05391708
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/185/GCF_002128185.1_ASM212818v1/GCF_002128185.1_ASM212818v1_genomic.fna.gz
# SAMN05391709
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/165/GCF_002128165.1_ASM212816v1/GCF_002128165.1_ASM212816v1_genomic.fna.gz
# SAMN05391710
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/285/GCF_002128285.1_ASM212828v1/GCF_002128285.1_ASM212828v1_genomic.fna.gz
# SAMN05391712
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/205/GCF_002128205.1_ASM212820v1/GCF_002128205.1_ASM212820v1_genomic.fna.gz
# SAMN05391714
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/235/GCF_002128235.1_ASM212823v1/GCF_002128235.1_ASM212823v1_genomic.fna.gz
# SAMN05391717
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/265/GCF_002128265.1_ASM212826v1/GCF_002128265.1_ASM212826v1_genomic.fna.gz
# SAMN05391720
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/085/GCF_002128085.1_ASM212808v1/GCF_002128085.1_ASM212808v1_genomic.fna.gz
# SAMN05391721
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/105/GCF_002128105.1_ASM212810v1/GCF_002128105.1_ASM212810v1_genomic.fna.gz
# SAMN05391741
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/128/125/GCF_002128125.1_ASM212812v1/GCF_002128125.1_ASM212812v1_genomic.fna.gz
# SAMN05391744
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/147/855/GCF_002147855.1_ASM214785v1/GCF_002147855.1_ASM214785v1_genomic.fna.gz
# SAMN06699082
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/090/215/GCF_002090215.1_ASM209021v1/GCF_002090215.1_ASM209021v1_genomic.fna.gz
# SAMN06699089
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/090/235/GCF_002090235.1_ASM209023v1/GCF_002090235.1_ASM209023v1_genomic.fna.gz
# SAMN06699090
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/090/275/GCF_002090275.1_ASM209027v1/GCF_002090275.1_ASM209027v1_genomic.fna.gz
# SAMN06699102
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/090/295/GCF_002090295.1_ASM209029v1/GCF_002090295.1_ASM209029v1_genomic.fna.gz
# SAMN06699128
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/090/315/GCF_002090315.1_ASM209031v1/GCF_002090315.1_ASM209031v1_genomic.fna.gz
# SAMN06699949
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/096/015/GCF_002096015.1_ASM209601v1/GCF_002096015.1_ASM209601v1_genomic.fna.gz
# SAMN06700070
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/095/995/GCF_002095995.1_ASM209599v1/GCF_002095995.1_ASM209599v1_genomic.fna.gz
# SAMN06700077
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/002/096/035/GCF_002096035.1_ASM209603v1/GCF_002096035.1_ASM209603v1_genomic.fna.gz
# SAMN02471521
# found 2 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/387/745/GCF_000387745.1_19294_v1/GCF_000387745.1_19294_v1_genomic.fna.gz
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/387/745/GCF_000387745.2_ASM38774v2/GCF_000387745.2_ASM38774v2_genomic.fna.gz
# SAMD00012611
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/283/755/GCF_000283755.1_ASM28375v1/GCF_000283755.1_ASM28375v1_genomic.fna.gz
# SAMN03284385
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/715/GCF_001272715.1_ASM127271v1/GCF_001272715.1_ASM127271v1_genomic.fna.gz
# SAMN03284386
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/735/GCF_001272735.1_ASM127273v1/GCF_001272735.1_ASM127273v1_genomic.fna.gz
# SAMN03284387
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/755/GCF_001272755.1_ASM127275v1/GCF_001272755.1_ASM127275v1_genomic.fna.gz
# SAMN03284388
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/775/GCF_001272775.1_ASM127277v1/GCF_001272775.1_ASM127277v1_genomic.fna.gz
# SAMN03284389
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/795/GCF_001272795.1_ASM127279v1/GCF_001272795.1_ASM127279v1_genomic.fna.gz
# SAMN03284391
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/815/GCF_001272815.1_ASM127281v1/GCF_001272815.1_ASM127281v1_genomic.fna.gz
# SAMN02603455
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/143/945/GCF_000143945.1_ASM14394v1/GCF_000143945.1_ASM14394v1_genomic.fna.gz
# SAMN03284384
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/835/GCF_001272835.1_ASM127283v1/GCF_001272835.1_ASM127283v1_genomic.fna.gz
# SAMN03284392
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/855/GCF_001272855.1_ASM127285v1/GCF_001272855.1_ASM127285v1_genomic.fna.gz
# SAMN02603304
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/027/345/GCF_000027345.1_ASM2734v1/GCF_000027345.1_ASM2734v1_genomic.fna.gz
# SAMN02604130
# found 3 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/331/085/GCF_000331085.1_ASM33108v1/GCF_000331085.1_ASM33108v1_genomic.fna.gz
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/331/085/GCF_000331085.3_ASM33108v2/GCF_000331085.3_ASM33108v2_genomic.fna.gz
# SAMN03284393
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/895/GCF_001272895.1_ASM127289v1/GCF_001272895.1_ASM127289v1_genomic.fna.gz
# SAMN02582400
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/733/995/GCF_000733995.1_ASM73399v1/GCF_000733995.1_ASM73399v1_genomic.fna.gz
# SAMN03284394
# found 1 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/272/915/GCF_001272915.1_ASM127291v1/GCF_001272915.1_ASM127291v1_genomic.fna.gz
# SAMN02471520
# found 2 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/319/675/GCF_000319675.1_v1/GCF_000319675.1_v1_genomic.fna.gz
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/319/675/GCF_000319675.2_ASM31967v2/GCF_000319675.2_ASM31967v2_genomic.fna.gz
# SAMN02471519
# found 2 ids
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/319/655/GCF_000319655.1_v3/GCF_000319655.1_v3_genomic.fna.gz
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/319/655/GCF_000319655.2_ASM31965v2/GCF_000319655.2_ASM31965v2_genomic.fna.gz
